# %% [markdown]
# # Problemas de distribución de probabilidad

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
from scipy.stats import binom

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dbinom(x, size, prob = 0.5):
    """
    Calcula la estimación puntual de la distribución binomial.
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calcula el acumulado de la distribución binomial.
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calcula la función cuantil a partir de la distribución binomial.
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Genera variables aleatorias a partir de la distribución binomial.
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       2 import numpy as np
#       4 np.random.seed(42)
# ----> 6 print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
#       7 print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
#       8 print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
#
# NameError: name 'dbinom' is not defined

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %%
# TODO

from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np

# Definir todas las funciones de probabilidad relacionadas con la distribución Normal.


def dnorm(x, mean = 0, sd = 1):
    """
    Calcula la Densidad de probabilidad en el punto x de la distribución Normal
    """
    resultado = norm.pdf(x, loc = mean, scale = sd)

    return resultado 

def pnorm(x, mean = 0, sd = 1):
    """
    Calcular la Probabilidad acumulada hasta q
    """
    resultado  = norm.cdf(x = x, loc = mean, scale = sd)

    return resultado 

def qnorm(p, mean = 0, sd = 1):
    """
    Calcular Cuantil: el valor x tal que la probabilidad acumulada es p
    """
    resultado  = norm.ppf(q = p, loc = mean, scale = sd)

    return resultado 

def rnorm(n, mean = 0, sd = 1):
    """
    Genera n valores aleatorios de la normal de la probabilidad acumulada
    """
    resultado  = norm.rvs(size = n, loc = mean, scale = sd)

    return resultado 

#Graficar

np.random.seed(42)

media = 0
sd = 1
data = np.arange(-6, 6, 0.01)

pmf = dnorm(data, mean = media, sd = sd)
cdf = pnorm(data, mean = media, sd = sd)
ppf = qnorm(data, mean = media, sd = sd)

fig, axis = plt.subplots(3, 1, figsize = (5,10))

axis[0].plot(data, pmf, "r-")
axis[1].plot(data, cdf, "b-")
axis[2].plot(data, ppf, "g-")

plt.tight_layout()
plt.show()

# %%
from scipy.stats import uniform

# Definir todas las funciones de probabilidad relacionadas con la distribución Uniforme.

def dunif(x, min = 0, max = 1):
    """
    Calcular la densidad en x de la distribución Uniforme
    """
    resultado1 = uniform.pdf(x, loc = min, scale = (max - min))

    return resultado1

def punif(q, min = 0, max = 1):
    """
    Calcular la Probabilidad acumulada hasta q de la distribución Uniforme
    """
    resultado1 = uniform.cdf(q, loc = min, scale = (max - min))
    return resultado1

def qunif(p, min = 0, max = 1):
    """
    Calcular el valor x tal que la probabilidad acumulada sea p de la distribución Uniforme
    """
    resultado1 = uniform.ppf(p, loc = min, scale = (max - min))

    return resultado1

def runif(n, min = 0, max = 1):
    """
    Calcular n valores aleatorios, todos con la misma probabilidad de la distribución Uniforme
    """
    resultado1 = uniform.rvs(loc = min, scale = (max - min), size = n)

    return resultado1

#Graficar

np.random.seed(42)

mini = 0
maxi = 1
data = np.arange(-6, 6, 0.01)

pmf = dunif(data, min = mini, max = maxi)
cdf = punif(data, min = mini, max = maxi)
ppf = qunif(data, min = mini, max = maxi)

fig, axis = plt.subplots(3, 1, figsize = (5, 10))

axis[0].plot(data, pmf, "r-")
axis[1].plot(data, cdf, "b-")
axis[2].plot(data, ppf, "g-")

plt.tight_layout()
plt.show()
